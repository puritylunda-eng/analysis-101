# %% [markdown]
# ## business understandingAdditional Information
#
# Bike sharing systems are new generation of traditional bike rentals where whole process from membership, rental and return back has become automatic. Through these systems, user is able to easily rent a bike from a particular position and return back at another position. Currently, there are about over 500 bike-sharing programs around the world which is composed of over 500 thousands bicycles. Today, there exists great interest in these systems due to their important role in traffic, environmental and health issues.
#
# Apart from interesting real world applications of bike sharing systems, the characteristics of data being generated by these systems make them attractive for the research. Opposed to other transport services such as bus or subway, the duration of travel, departure and arrival position is explicitly recorded in these systems. This feature turns bike sharing system into a virtual sensor network that can be used for sensing mobility in the city. Hence, it is expected that most of important events in the city could be detected via monitoring these data.
#
#
# source: https://archive.ics.uci.edu/dataset/275/bike+sharing+dataset

# %% [markdown]
# # **Data Understanding**
#
# - loading
# - head and tail( glimpse of how the dat alooks like)
# - shape
# - info()
# - data types
# - descritptive stats (categorical)
# - descritptive stats (numerical)
# - missing values (data integrity)
# - duplicate(data integrity)
#
# - visualization

# %% [markdown]
# ## loading libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##  load data sets

# %%
bikesharingperday_df=pd.read_csv("data/day.csv")

# %%
bikesharingperhour_df= pd.read_csv("data/hour.csv")

# %% [markdown]
# ## glimplse of the data- head,tail (day)  data set

# %%
bikesharingperday_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
bikesharingperday_df.tail()
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 726           2  0.254167  0.226642  0.652917   0.350133     247        1867
# 727           2  0.253333  0.255046  0.590000   0.155471     644        2451
# 728           2  0.253333  0.242400  0.752917   0.124383     159        1182
# 729           1  0.255833  0.231700  0.483333   0.350754     364        1432
# 730           2  0.215833  0.223487  0.577500   0.154846     439        2290
#
#       cnt
# 726  2114
# 727  3095
# 728  1341
# 729  1796
# ...

# %% [markdown]
# ## glimplse hour dataset

# %%
bikesharingperhour_df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
bikesharingperhour_df.tail()
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 17374           1           2  0.26  0.2576  0.60     0.1642      11
# 17375           1           2  0.26  0.2576  0.60     0.1642       8
# 17376           1           1  0.26  0.2576  0.60     0.1642       7
# 17377           1           1  0.26  0.2727  0.56     0.1343      13
# 17378           1           1  0.26  0.2727  0.65     0.1343      12
#
#        registered  cnt
# 17374         108  119
# 17375          81   89
# 17376          83   90
# 17377          48   61
# 17378          37   49

# %% [markdown]
# ## dimensions and columns and data types and info

# %%
rows,columns=bikesharingperday_df.shape ## day dataset
output=f"RECORDS:{rows}|| FEATURES {columns}"
print(output)
# Out:
# RECORDS:731|| FEATURES 16

# %%
rows,columns=bikesharingperhour_df.shape ## hour dataset
output=f"RECORDS:{rows}|| FEATURES {columns}"
print(output)
# Out:
# RECORDS:17379|| FEATURES 17

# %%
bikesharingperhour_df.columns ## hour dataset
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='str')

# %%
bikesharingperday_df.columns ## day dataset
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='str')

# %%
bikesharingperhour_df.dtypes ## hour dataset
# Out:
# instant         int64
# dteday            str
# season          int64
# yr              int64
# mnth            int64
# hr              int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
bikesharingperday_df.dtypes
# Out:
# instant         int64
# dteday            str
# season          int64
# yr              int64
# mnth            int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
bikesharingperday_df.info() ## day data sets
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    str
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), str(1)
# memory usage: 91.5 KB

# %%
bikesharingperhour_df.info() ## hour data sets
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  str
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), str(1)
# memory usage: 2.3 MB

# %% [markdown]
# ## missing values and duplicates

# %%
bikesharingperday_df.isna().sum() ## no null values ## day
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
bikesharingperhour_df.isna().sum() ## no null values ## hour
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
bikesharingperday_df.duplicated().sum() # here we have no duplicates # day data sets
# Out:
# np.int64(0)

# %%
bikesharingperhour_df.duplicated().sum() # here we have no duplicates # hour datasets
# Out:
# np.int64(0)

# %% [markdown]
# ## descriptive stats (numerical&categorial)

# %%
bikesharingperhour_df.values
# Out:
# array([[1, '2011-01-01', 1, ..., 3, 13, 16],
#        [2, '2011-01-01', 1, ..., 8, 32, 40],
#        [3, '2011-01-01', 1, ..., 5, 27, 32],
#        ...,
#        [17377, '2012-12-31', 1, ..., 7, 83, 90],
#        [17378, '2012-12-31', 1, ..., 13, 48, 61],
#        [17379, '2012-12-31', 1, ..., 12, 37, 49]],
#       shape=(17379, 17), dtype=object)

# %%
bikesharingperday_df.values ## day data sets
# Out:
# array([[1, '2011-01-01', 1, ..., 331, 654, 985],
#        [2, '2011-01-02', 1, ..., 131, 670, 801],
#        [3, '2011-01-03', 1, ..., 120, 1229, 1349],
#        ...,
#        [729, '2012-12-29', 1, ..., 159, 1182, 1341],
#        [730, '2012-12-30', 1, ..., 364, 1432, 1796],
#        [731, '2012-12-31', 1, ..., 439, 2290, 2729]],
#       shape=(731, 16), dtype=object)

# %%
bikesharingperhour_df.describe() ## hour data set
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %% [markdown]
# insight:
#
# **count**
# - an average of i89 bikes rented per hour
# - least(min) rented 1 bike per hour
# - highest number of bikes rented per hour is 977
# - 50 % of the bikes rented per hour fall below 142
# - iqr= 241 bikes rented per hour
# - A sd of 181 == Bike demand varies a lot, meaning some hours have very high demand while others have very low demand, possiblity of outliers.
#
# **users**
# - we have casual and registered users
# - from a total of 17379 , casual has a high of 367 users and averagely 35 users per hour while registered users has an high of 886 users and an average of 153.
# - Casual users are much fewer compared to registered users.
# - More registered users, meaning frequent riders use the system regularly.
#
# **weather**
# - temperature- highest of 1 and a minimum of 0.02. and averagely 0.049, implying the bike usage per hour varies with temperature more rides/rentals in a moderate temp
# - humidity- an average of 0.627229 , high humidities attarct less/no rentals because its uncomfortable weather
# - winds- a Mean of 0.19 and high of 0.85 ,strong winds may discourage bike riding.
#
# **hour of day**- 0 to 23hr
# - we have a mean (close to th 50% percentile== 12) of 11 th hour to mean majority of rentals happen by/around  midday
# - the rentals peak at the 23rd hour probably people commuting from work.
#
# **working day**
# - all percentiles close to 1 and an average of 0.682721 implying ,commuting to work likely influences bike renting.
#
# **week day**
# - highest rental per hour during the 6th day of the week
# - averagely the 3rd day of the week has most rentals per hour

# %%
bikesharingperhour_df.describe(include='object')
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_9844\671235410.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   bikesharingperhour_df.describe(include='object')
#             dteday
# count        17379
# unique         731
# top     2011-01-01
# freq            24

# %% [markdown]
# insight:
# - 01/01/2011 had the highest rentals

# %%
bikesharingperday_df.describe() ## day dataset
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %% [markdown]
# insights:
#
# **count**
# - a mean of 4504 bikes per day, minimum bike rental per day 22 bikes and an high of 8714 bikes per day.
# - the sd of 1937 there is a large variation, meaning demand fluctuates depending on factors like season, weather, or working days.
#
# **users**
# - Casual Users are averagely 848 per day and an high of 3410 bikes rented per day and a minimum of 2 bikes
# - Registered Users are averagely 3656 per day and an high of 6946 bikes rented per day and a minimum of 20 bikes
# - Bike sharing is used mainly by registered commuters rather than casual users.
#
# **weather**
# - ranging from 1 to 3
# - a Mean of 1.39, meaning Most days have clear weather.
#
# **working day**
# - a mean of 0.683995 , about 68% of the days are working days - bike sharing is mostly used on working days

# %%
bikesharingperday_df.describe(include='object')
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_9844\3826426910.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   bikesharingperday_df.describe(include='object')
#             dteday
# count          731
# unique         731
# top     2011-01-01
# freq             1

# %% [markdown]
# ## visualization

# %%
bikesharingperhour_df.groupby("hr")["cnt"].mean().plot(kind="line")

plt.title("Average Bike Rentals by Hour")
plt.xlabel("Hour of the Day")
plt.ylabel("Average Rentals")
plt.show()

# %%
plt.hist(bikesharingperhour_df['cnt'], bins=30)
plt.title("Distribution of Total Bike Rentals")
plt.xlabel("Number of Rentals")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# insight:
# - right skewedness
# - possibility of outliers probably affected by weekday/workingday, and mostly the weather

# %%
plt.hist(bikesharingperday_df['cnt'], bins=30)
plt.title("Distribution of Total Bike Rentals")
plt.xlabel("Number of Rentals")
plt.ylabel("Frequency")
plt.show()

# %%
bikesharingperhour_df.groupby("season")["cnt"].mean().plot(kind="bar")

plt.title("Average Bike Rentals by Season")
plt.xlabel("Season")
plt.ylabel("Average Rentals")
plt.show()

# %% [markdown]
# insight:
# - 1: Clear, Few clouds, Partly cloudy, Partly cloudy
# - 2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
# - 3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds
# - 4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog

# %%
user_types = ['Casual', 'Registered']
values = [bikesharingperday_df['casual'].mean(), bikesharingperday_df['registered'].mean()]

plt.bar(user_types, values)

plt.title("Average Bike Rentals: Casual vs Registered Users")
plt.xlabel("User Type")
plt.ylabel("Average Number of Rentals")

plt.show()

# %%
sns.barplot(x=['Casual','Registered'], 
            y=[bikesharingperhour_df['casual'].mean(), bikesharingperhour_df['registered'].mean()])

plt.title("Average Casual vs Registered Users")
plt.ylabel("Average Rentals")
plt.show()

# %%
sns.histplot(bikesharingperhour_df['cnt'], kde=True)

plt.title("Distribution of Total Bike Rentals")
plt.show()

# %% [markdown]
# insight:
# - postivley skewed

# %%
sns.histplot(bikesharingperday_df['cnt'], kde=True)

plt.title("Distribution of Total Bike Rentals")
plt.show()

# %% [markdown]
# insight:
# - uniformly distibuted

# %%
sns.histplot(bikesharingperday_df['temp'], kde=True)

plt.title("Temperature Distribution")
plt.show()

# %%
sns.histplot(bikesharingperhour_df['temp'], kde=True)

plt.title("Temperature Distribution")
plt.show()

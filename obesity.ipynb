# %% [markdown]
# **BUSINESS UNDERSTANDING**
#
# This dataset include data for the estimation of obesity levels in individuals from the countries of Mexico, Peru and Colombia, based on their eating habits and physical condition.
# This dataset include data for the estimation of obesity levels in individuals from the countries of Mexico, Peru and Colombia, based on their eating habits and physical condition. The data contains 17 attributes and 2111 records, the records are labeled with the class variable NObesity (Obesity Level), that allows classification of the data using the values of Insufficient Weight, Normal Weight, Overweight Level I, Overweight Level II, Obesity Type I, Obesity Type II and Obesity Type III. 77% of the data was generated synthetically using the Weka tool and the SMOTE filter, 23% of the data was collected directly from users through a web platform.
# SOURCE

# %% [markdown]
# # **Data Understanding**
#
# - loading
# - head and tail( glimpse of how the dat alooks like)
# - shape
# - info()
# - data types
# - descritptive stats (categorical)
# - descritptive stats (numerical)
# - missing values (data integrity)
# - duplicate(data integrity)
# - visualization

# %% [markdown]
# **LOADING LIBRARIES**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# LOADING DATASETS

# %%
obesity_df=pd.read_csv("data/ObesityDataSet_raw_and_data_sinthetic.csv")

# %% [markdown]
# glimplse of the data

# %%
obesity_df.head(5)
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# ...

# %%
obesity_df.tail(5)
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
#      FAVC  FCVC  NCP       CAEC SMOKE      CH2O SCC       FAF       TUE  \
# 2106  yes   3.0  3.0  Sometimes    no  1.728139  no  1.676269  0.906247
# 2107  yes   3.0  3.0  Sometimes    no  2.005130  no  1.341390  0.599270
# 2108  yes   3.0  3.0  Sometimes    no  2.054193  no  1.414209  0.646288
# 2109  yes   3.0  3.0  Sometimes    no  2.852339  no  1.139107  0.586035
# 2110  yes   3.0  3.0  Sometimes    no  2.863513  no  1.026452  0.714137
#
#            CALC                 MTRANS        NObeyesdad
# ...

# %% [markdown]
# ## dimensions and columns and data types and info

# %%
rows,columns=obesity_df.shape 
output=f"RECORDS:{rows}|| FEATURES {columns}"
print(output)
# Out:
# RECORDS:2111|| FEATURES 17

# %%
obesity_df.columns
# Out:
# Index(['Gender', 'Age', 'Height', 'Weight', 'family_history_with_overweight',
#        'FAVC', 'FCVC', 'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE',
#        'CALC', 'MTRANS', 'NObeyesdad'],
#       dtype='str')

# %%
obesity_df.dtypes
# Out:
# Gender                                str
# Age                               float64
# Height                            float64
# Weight                            float64
# family_history_with_overweight        str
# FAVC                                  str
# FCVC                              float64
# NCP                               float64
# CAEC                                  str
# SMOKE                                 str
# CH2O                              float64
# SCC                                   str
# FAF                               float64
# TUE                               float64
# CALC                                  str
# MTRANS                                str
# NObeyesdad                            str
# dtype: object

# %%
obesity_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   str
#  1   Age                             2111 non-null   float64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2111 non-null   str
#  5   FAVC                            2111 non-null   str
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   CAEC                            2111 non-null   str
#  9   SMOKE                           2111 non-null   str
#  10  CH2O                            2111 non-null   float64
#  11  SCC                             2111 non-null   str
# ...

# %% [markdown]
# ## missing values and duplicates

# %%
obesity_df.isna().sum()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %% [markdown]
# insights:
# - data set has no missing values

# %%
obesity_df.duplicated().sum()
# Out:
# np.int64(24)

# %% [markdown]
# insight:
# - dataset has 24 duplicated values

# %% [markdown]
# ## descriptive stats (numerical&categorial)

# %%
obesity_df.describe()
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2111.000000  2111.000000  2111.000000  2111.000000  2111.000000
# mean     24.312600     1.701677    86.586058     2.419043     2.685628
# std       6.345968     0.093305    26.191172     0.533927     0.778039
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      19.947192     1.630000    65.473343     2.000000     2.658738
# 50%      22.777890     1.700499    83.000000     2.385502     3.000000
# 75%      26.000000     1.768464   107.430682     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE
# count  2111.000000  2111.000000  2111.000000
# mean      2.008011     1.010298     0.657866
# std       0.612953     0.850592     0.608927
# min       1.000000     0.000000     0.000000
# 25%       1.584812     0.124505     0.000000
# 50%       2.000000     1.000000     0.625350
# ...

# %% [markdown]
# insights:
#
# **age**
# - avearagely people ar of age 24 years
# - the oldest is at 61 years and youngest at 14 years
# - 50 % fall at 22 years  heavily skewed toward young people
# **height**
# - averagely people are of  1.70 m height
# - tallest at 1.98 and shortest at 1.45 m
# - 50 % of the people are 1.70
# - probably a normal distribution
#
# **weight**
# - averagely individual here weigh  86.6 kg, the heaviest being 173 kg and lightest at 39 kgs
# - the sd is at 26.19 implying its far from the mean  and presence of outliers
#
# **Do you usually eat vegetables in your meals?**FCVC
# - on a scale oh 1 to 3 we have a mean of 2.419043 implying a moderate vegetable intake
#
# **How many main meals do you have daily?**NCP
# - highest number of meals in a day is at 4 meals , lowest at 1 meal
# - the average is at 2.685628 , and 50% fall at 3 meals a day
#
# **How much water do you drink daily?**CH2O
# - mean is at 2 litres in arange of 1l to 3 l
# - 50 % fall at 2 litres
#
# **FAF** - How often do you have physical activity?
# - range of 1 to 3
# - mean is at 1
# - 25% fall below 0.12  very low physical activity
# - Many individuals are inactive or low activity strong risk factor for obesity
#
# **tue** How much time do you use technological devices such as cell phone, videogames, television, computer and others?
# - mean of 0.657866
# - highest duration at 2.000000

# %%
obesity_df.describe(include='object')
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_15312\3578292103.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   obesity_df.describe(include='object')
#        Gender family_history_with_overweight  FAVC       CAEC SMOKE   SCC  \
# count    2111                           2111  2111       2111  2111  2111
# unique      2                              2     2          4     2     2
# top      Male                            yes   yes  Sometimes    no    no
# freq     1068                           1726  1866       1765  2067  2015
#
# ...

# %% [markdown]
# insight:
#
# **gender**
# - we have 2 genders female and male
# - most individuals are male
#
# **family history**
# - Yes: 1,726 implying  family/genetic history lifestyle plays a big role
#
# **high calory foods frequently**
# - Most individuals(1866 out of the 2111) consume high-calorie food frequently may contribute to higher obesity levels
#
# **Do you eat any food between meals?**
# - sometimes people( 1765 out of the 2111 individuals) eat food in between meals
#
# **smoke**
# - very few smokers
# - 2067 out othe 2111 do not smoke
#
# **transport means**
# - most of the individuals( 1580 out of 2111) use public transportation.
#
# **Obesity level**
# - out of the 7 levels the most recurring one is Obesity_Type_I
# - 351 have Obesity_Type_I
#
# **How often do you drink alcohol?**
# - 1401 individuals out of the 2111 sometimes take alcohol
# - Moderate alcohol consumption
#
# **Do you monitor the calories you eat daily?** scc
# - most individuals do not track their calories intake

# %% [markdown]
# ## visualizations

# %%
obesity_df_BMI= obesity_df['Weight'] / (obesity_df['Height'] ** 2)
print(obesity_df_BMI)
# Out:
# 0       24.386526
# 1       24.238227
# 2       23.765432
# 3       26.851852
# 4       28.342381
#           ...
# 2106    44.901475
# 2107    43.741923
# 2108    43.543817
# 2109    44.071535
# 2110    44.144338
# Length: 2111, dtype: float64

# %%
obesity_df_BMI.head()
# Out:
# 0    24.386526
# 1    24.238227
# 2    23.765432
# 3    26.851852
# 4    28.342381
# dtype: float64

# %% [markdown]
# gender and obesity

# %%
plt.figure(figsize=(8,4))
sns.countplot(x="NObeyesdad", hue="Gender", data=obesity_df)
plt.xticks(rotation=45)
plt.title("Gender vs Obesity Level")
plt.show()

# %% [markdown]
# family history and obesity ## family history contributes to variety of obesity

# %%
plt.figure(figsize=(8,4))
sns.countplot(x="NObeyesdad", hue="family_history_with_overweight", data=obesity_df)
plt.xticks(rotation=45)
plt.title("Family History vs Obesity")
plt.show()

# %% [markdown]
# tue and obesity

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x="NObeyesdad", y="TUE", data=obesity_df)
plt.xticks(rotation=45)
plt.title("Technology Use vs Obesity")
plt.show()

# %%
sns.boxplot(x='NObeyesdad', y='BMI', data=obesity_df)
plt.xticks(rotation=45)
plt.title("BMI vs Obesity Level")
plt.show()

# %% [markdown]
# insight:-
# - increase in BMI across obesity types, confirming that BMI is a strong predictor of obesity levels.

# %% [markdown]
# ## weight

# %%
sns.histplot(obesity_df['Weight'], kde=True)
plt.title("Weight Distribution")
plt.show()

# %% [markdown]
# ## age distribution

# %%
sns.histplot(obesity_df['Age'], kde=True)
plt.title("Age Distribution")
plt.show()

# %% [markdown]
# insight;
# - most individuals in this data set are young adults

# %% [markdown]
# ## Obesity Levels

# %%
sns.boxplot(x='NObeyesdad', y='Weight', data=obesity_df)
plt.xticks(rotation=100)
plt.title("Weight vs Obesity Level")
plt.show()

# %% [markdown]
# ## Physical Activity vs Obesity

# %%
sns.boxplot(x='NObeyesdad', y='FAF', data=obesity_df)
plt.xticks(rotation=45)
plt.title("Physical Activity vs Obesity")
plt.show()

# %% [markdown]
# ## transport

# %%
sns.countplot(x='MTRANS', hue='NObeyesdad', data=obesity_df)
plt.xticks(rotation=45)
plt.title("Transport vs Obesity")
plt.show()

# %% [markdown]
# ## lifestyles

# %%
sns.countplot(x='CAEC', hue='NObeyesdad', data=obesity_df)
plt.title("Snacking vs Obesity")
plt.show()

# %% [markdown]
# ## faf vs weight

# %%
sns.barplot(x='FAF', y='Weight', hue='NObeyesdad', data=obesity_df)
plt.title("Physical Activity vs Weight")
plt.show()

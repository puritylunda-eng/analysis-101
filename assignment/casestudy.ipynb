# %%
import pandas as pd #importing pandas

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### loading data

# %%
#data frame
movie_df=pd.read_csv("data/movie.csv")
user_df=pd.read_csv("data/user.csv")
ratings_df=pd.read_csv("data/ratings.csv")

# %% [markdown]
# ## rows

# %%
#get firt 5 rows user data set head and
user_df.head(5)
# Out:
#    user id  age gender  occupation zip code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %% [markdown]
# ## tails

# %%
#5 rows from bottom of data set
user_df.tail(5)
# Out:
#      user id  age gender     occupation zip code
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841

# %% [markdown]
# ## shape of data sets

# %%
#shape of data (rows,columns)
user_df.shape
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %% [markdown]
# ## data types

# %%
###data types
user_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 943 entries, 0 to 942
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user id     943 non-null    int64
#  1   age         943 non-null    int64
#  2   gender      943 non-null    str
#  3   occupation  943 non-null    str
#  4   zip code    943 non-null    str
# dtypes: int64(2), str(3)
# memory usage: 37.0 KB

# %%
user_df.columns
user_df["age"]
type(user_df["age"])
# Out:
# pandas.Series

# %%
user_df[["age","occupation"]].dtypes
# Out:
# age           int64
# occupation      str
# dtype: object

# %% [markdown]
# ## retrieving a row from the data

# %%
user_df[["age","occupation"]].loc[9]
# Out:
# age               53
# occupation    lawyer
# Name: 9, dtype: object

# %% [markdown]
# ## descriptive stats

# %%
user_df["age"].mean()
# Out:
# np.float64(34.05196182396607)

# %%
user_df["age"].mode()
# Out:
# 0    30
# Name: age, dtype: int64

# %%
user_df["age"].median()
# Out:
# np.float64(31.0)

# %%
user_df.columns
# Out:
# Index(['user id', 'age', 'gender', 'occupation', 'zip code'], dtype='str')

# %% [markdown]
# ## statstical summary

# %%
user_df.describe()
# Out:
#           user id         age
# count  943.000000  943.000000
# mean   472.000000   34.051962
# std    272.364951   12.192740
# min      1.000000    7.000000
# 25%    236.500000   25.000000
# 50%    472.000000   31.000000
# 75%    707.500000   43.000000
# max    943.000000   73.000000

# %%
user_df.loc[user_df["age"]>=30]
userthirtyyrsold_df= user_df.loc[user_df["age"]==30]
print(f'there are {len(userthirtyyrsold_df)} workers of age 30')
# Out:
# there are 39 workers of age 30

# %% [markdown]
# ## visualization

# %%
plt.hist(userthirtyyrsold_df['occupation'])
plt.xlabel("occupation")
plt.ylabel("f")
plt.title('age Distribution')
plt.show()
